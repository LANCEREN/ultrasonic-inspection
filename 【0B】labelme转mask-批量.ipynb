# %% [markdown]
# # Labelme转mask-批量

# %% [markdown]
# ## 下载样例数据集

# %%
# !rm -rf Watermelon87_Semantic_Seg_Labelme.zip Watermelon87_Semantic_Seg_Labelme # 删除原有压缩包和文件夹
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/dataset/watermelon/Watermelon87_Semantic_Seg_Labelme.zip # 下载压缩包
# !unzip Watermelon87_Semantic_Seg_Labelme.zip >> /dev/null # 解压压缩包
# !rm -rf Watermelon87_Semantic_Seg_Labelme.zip # 删除压缩包
# Out:
# --2023-06-09 09:09:27--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/dataset/watermelon/Watermelon87_Semantic_Seg_Labelme.zip
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 12978831 (12M) [application/zip]
# 正在保存至: “Watermelon87_Semantic_Seg_Labelme.zip”
#
# Watermelon87_Semant 100%[===================>]  12.38M  26.4MB/s    用时 0.5s
#
# 2023-06-09 09:09:28 (26.4 MB/s) - 已保存 “Watermelon87_Semantic_Seg_Labelme.zip” [12978831/12978831])

# %% [markdown]
# ## 查看数据集目录结构

# %%
import os
import shutil

# %%
def extract_files_by_extension(source_folder, destination_folder, extension=".txt"):
    # 确保目标文件夹存在，如果不存在则创建
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # 获取源文件夹中的所有文件
    files = os.listdir(source_folder)

    # 提取特定格式的文件到目标文件夹
    for file in files:
        if file.endswith(extension):
            source_path = os.path.join(source_folder, file)
            destination_path = os.path.join(destination_folder, file)
            shutil.move(source_path, destination_path)
            print(f"Moved: {file}")

# 使用示例
source_directory = "mmsegmentation/LSR16F656"  # 替换为源文件夹的路径
# destination_directory = "mmsegmentation/LSR16F656/images"  # 替换为目标文件夹的路径
# file_extension = ".tiff"  # 替换为你要提取的文件扩展名

destination_directory = "mmsegmentation/LSR16F656/labelme_jsons"  # 替换为目标文件夹的路径
file_extension = ".json"  # 替换为你要提取的文件扩展名

extract_files_by_extension(source_directory, destination_directory, file_extension)
# Out:
# Moved: 001 (502).json
# Moved: 001 (503).json
# Moved: 001 (505).json
# Moved: 001 (506).json
# Moved: 001 (507).json
# Moved: 001 (508).json
# Moved: 001 (510).json
# Moved: 001 (511).json
# Moved: 001 (515).json
# Moved: 001 (520).json
# Moved: 001 (525).json
# Moved: 001 (527).json
# Moved: 001 (530).json
# Moved: 001 (531).json
# Moved: 001 (535).json
# Moved: 001 (537).json
# Moved: 001 (539).json
# Moved: 001 (543).json
# Moved: 001 (550).json
# Moved: 001 (549).json
# Moved: 001 (546).json
# Moved: 001 (553).json
# Moved: 001 (557).json
# Moved: 001 (556).json
# Moved: 001 (533).json
# Moved: 001 (561).json
# Moved: 001 (560).json
# Moved: 001 (562).json
# Moved: 001 (563).json
# Moved: 001 (564).json
# Moved: 001 (521).json
# Moved: 001 (526).json
# Moved: 001 (528).json
# Moved: 001 (534).json
# Moved: 001 (536).json
# Moved: 001 (538).json
# Moved: 001 (540).json
# Moved: 001 (544).json
# Moved: 001 (547).json
# Moved: 001 (545).json
# Moved: 001 (551).json
# Moved: 001 (559).json
# Moved: 001 (558).json
# Moved: 001 (554).json
# Moved: 001 (512).json
# Moved: 001 (513).json
# Moved: 001 (516).json
# Moved: 001 (514).json
# Moved: 001 (519).json
# Moved: 001 (517).json
# Moved: 001 (568).json
# Moved: 001 (566).json
# Moved: 001 (565).json
# Moved: 001 (567).json
# Moved: 001 (572).json
# Moved: 001 (574).json
# Moved: 001 (573).json
# Moved: 001 (569).json
# Moved: 001 (577).json
# Moved: 001 (571).json
# Moved: 001 (580).json
# Moved: 001 (581).json
# Moved: 001 (584).json
# Moved: 001 (576).json
# Moved: 001 (582).json
# Moved: 001 (591).json
# Moved: 001 (587).json
# Moved: 001 (589).json
# Moved: 001 (583).json
# Moved: 001 (593).json
# Moved: 001 (588).json
# Moved: 001 (590).json
# Moved: 001 (594).json
# Moved: 001 (585).json
# Moved: 001 (598).json
# Moved: 001 (596).json
# Moved: 001 (601).json
# Moved: 001 (595).json
# Moved: 001 (610).json
# Moved: 001 (607).json
# Moved: 001 (605).json
# Moved: 001 (608).json
# Moved: 001 (606).json
# Moved: 001 (599).json
# Moved: 001 (618).json
# Moved: 001 (616).json
# Moved: 001 (603).json
# Moved: 001 (602).json
# Moved: 001 (609).json
# Moved: 001 (611).json
# Moved: 001 (615).json
# Moved: 001 (612).json
# Moved: 001 (620).json
# Moved: 001 (624).json
# Moved: 001 (617).json
# Moved: 001 (604).json
# Moved: 001 (622).json
# Moved: 001 (600).json
# Moved: 001 (631).json
# Moved: 001 (633).json
# Moved: 001 (597).json
# Moved: 001 (619).json
# Moved: 001 (637).json
# Moved: 001 (613).json
# Moved: 001 (636).json
# Moved: 001 (625).json
# Moved: 001 (628).json
# Moved: 001 (629).json
# Moved: 001 (630).json
# Moved: 001 (627).json
# Moved: 001 (623).json
# Moved: 001 (656).json
# Moved: 001 (645).json
# Moved: 001 (646).json
# Moved: 001 (634).json
# Moved: 001 (643).json
# Moved: 001 (657).json
# Moved: 001 (647).json
# Moved: 001 (649).json
# Moved: 001 (659).json
# Moved: 001 (660).json
# Moved: 001 (653).json
# Moved: 001 (648).json
# Moved: 001 (658).json
# Moved: 001 (650).json
# Moved: 001 (679).json
# Moved: 001 (661).json
# Moved: 001 (654).json
# Moved: 001 (675).json
# Moved: 001 (680).json
# Moved: 001 (664).json
# Moved: 001 (671).json
# Moved: 001 (665).json
# Moved: 001 (666).json
# Moved: 001 (668).json
# Moved: 001 (655).json
# Moved: 001 (685).json
# Moved: 001 (674).json
# Moved: 001 (663).json
# Moved: 001 (688).json
# Moved: 001 (711).json
# Moved: 001 (669).json
# Moved: 001 (662).json
# Moved: 001 (681).json
# Moved: 001 (701).json
# Moved: 001 (687).json
# Moved: 001 (716).json
# Moved: 001 (683).json
# Moved: 001 (677).json
# Moved: 001 (704).json
# Moved: 001 (684).json
# Moved: 001 (697).json
# Moved: 001 (705).json
# Moved: 001 (673).json
# Moved: 001 (693).json
# Moved: 001 (700).json
# Moved: 001 (667).json
# Moved: 001 (676).json
# Moved: 001 (686).json
# Moved: 001 (703).json
# Moved: 001 (723).json
# Moved: 001 (699).json
# Moved: 001 (702).json
# Moved: 001 (708).json
# Moved: 001 (717).json
# Moved: 001 (678).json
# Moved: 001 (692).json
# Moved: 001 (709).json
# Moved: 001 (718).json
# Moved: 001 (727).json
# Moved: 001 (706).json
# Moved: 001 (707).json
# Moved: 001 (691).json
# Moved: 001 (710).json
# Moved: 001 (696).json
# Moved: 001 (726).json
# Moved: 001 (729).json
# Moved: 001 (720).json
# Moved: 001 (715).json
# Moved: 001 (731).json
# Moved: 001 (719).json
# Moved: 001 (714).json
# Moved: 001 (738).json
# Moved: 001 (724).json
# Moved: 001 (694).json
# Moved: 001 (736).json
# Moved: 001 (725).json
# Moved: 001 (695).json
# Moved: 001 (735).json
# Moved: 001 (757).json
# Moved: 001 (721).json
# Moved: 001 (737).json
# Moved: 001 (733).json
# Moved: 001 (746).json
# Moved: 001 (748).json
# Moved: 001 (730).json
# Moved: 001 (759).json
# Moved: 001 (751).json
# Moved: 001 (713).json
# Moved: 001 (760).json
# Moved: 001 (742).json
# Moved: 001 (744).json
# Moved: 001 (752).json
# Moved: 001 (754).json
# Moved: 001 (753).json
# Moved: 001 (758).json
# Moved: 001 (741).json
# Moved: 001 (756).json
# Moved: 001 (770).json
# Moved: 001 (740).json
# Moved: 001 (765).json
# Moved: 001 (762).json
# Moved: 001 (763).json
# Moved: 001 (761).json
# Moved: 001 (764).json
# Moved: 001 (768).json
# Moved: 001 (776).json
# Moved: 001 (766).json
# Moved: 001 (769).json
# Moved: 001 (775).json
# Moved: 001 (767).json
# Moved: 001 (773).json
# Moved: 001 (782).json
# Moved: 001 (777).json
# Moved: 001 (780).json
# Moved: 001 (785).json
# Moved: 001 (778).json
# Moved: 001 (786).json
# Moved: 001 (783).json
# Moved: 001 (788).json
# Moved: 001 (774).json
# Moved: 001 (787).json
# Moved: 001 (747).json
# Moved: 001 (745).json
# Moved: 001 (749).json
# Moved: 001 (750).json
# Moved: 001 (789).json
# Moved: 001 (791).json
# Moved: 001 (790).json
# Moved: 001 (793).json
# Moved: 001 (794).json
# Moved: 001 (795).json
# Moved: 001 (796).json
# Moved: 001 (798).json
# Moved: 001 (799).json
# Moved: 001 (800).json
# Moved: 001 (801).json
# Moved: 001 (802).json
# Moved: 001 (804).json
# Moved: 001 (805).json
# Moved: 001 (806).json
# Moved: 001 (807).json
# Moved: 001 (808).json
# Moved: 001 (809).json
# Moved: 001 (810).json
# Moved: 001 (811).json
# Moved: 001 (812).json
# Moved: 001 (813).json
# Moved: 001 (814).json
# Moved: 001 (815).json
# Moved: 001 (816).json
# Moved: 001 (818).json
# Moved: 001 (820).json
# Moved: 001 (821).json
# Moved: 001 (825).json
# Moved: 001 (823).json
# Moved: 001 (826).json
# Moved: 001 (829).json
# Moved: 001 (830).json
# Moved: 001 (833).json
# Moved: 001 (831).json
# Moved: 001 (834).json
# Moved: 001 (835).json
# Moved: 001 (836).json
# Moved: 001 (837).json
# Moved: 001 (840).json
# Moved: 001 (843).json
# Moved: 001 (844).json
# Moved: 001 (849).json
# Moved: 001 (850).json
# Moved: 001 (859).json
# Moved: 001 (857).json
# Moved: 001 (861).json
# Moved: 001 (865).json
# Moved: 001 (891).json
# Moved: 001 (862).json
# Moved: 001 (890).json
# Moved: 001 (930).json
# Moved: 001 (900).json
# Moved: 001 (938).json
# Moved: 001 (898).json
# Moved: 001 (907).json
# Moved: 001 (933).json
# Moved: 001 (920).json
# Moved: 001 (940).json
# Moved: 001 (929).json
# Moved: 001 (939).json
# Moved: 001 (903).json
# Moved: 001 (943).json
# Moved: 001 (944).json
# Moved: 001 (942).json
# Moved: 001 (960).json
# Moved: 001 (946).json
# Moved: 001 (951).json
# Moved: 001 (969).json
# Moved: 001 (967).json
# Moved: 001 (959).json
# Moved: 001 (972).json
# Moved: 001 (986).json
# Moved: 001 (968).json
# Moved: 001 (975).json
# Moved: 001 (970).json
# Moved: 001 (985).json
# Moved: 001 (1009).json
# Moved: 001 (992).json
# Moved: 001 (1014).json
# Moved: 001 (991).json
# Moved: 001 (995).json
# Moved: 001 (994).json
# Moved: 001 (1019).json
# Moved: 001 (1024).json
# Moved: 001 (1025).json
# Moved: 001 (1036).json
# Moved: 001 (1027).json
# Moved: 001 (1026).json
# Moved: 001 (1067).json
# Moved: 001 (1028).json
# Moved: 001 (1037).json
# Moved: 001 (1061).json
# Moved: 001 (1031).json
# Moved: 001 (1065).json
# Moved: 001 (1034).json
# Moved: 001 (1087).json
# Moved: 001 (1068).json
# Moved: 001 (1084).json
# Moved: 001 (1090).json
# Moved: 001 (1077).json
# Moved: 001 (1078).json
# Moved: 001 (1086).json
# Moved: 001 (1083).json
# Moved: 001 (1085).json
# Moved: 001 (822).json
# Moved: 001 (1140).json
# Moved: 001 (1093).json
# Moved: 001 (1113).json
# Moved: 001 (1117).json
# Moved: 001 (1104).json
# Moved: 001 (1122).json
# Moved: 001 (1092).json
# Moved: 001 (1109).json
# Moved: 001 (1112).json
# Moved: 001 (1144).json
# Moved: 001 (1111).json
# Moved: 001 (1132).json
# Moved: 001 (1180).json
# Moved: 001 (1110).json
# Moved: 001 (1123).json
# Moved: 001 (1097).json
# Moved: 001 (1152).json
# Moved: 001 (1163).json
# Moved: 001 (1145).json
# Moved: 001 (1172).json
# Moved: 001 (1162).json
# Moved: 001 (1173).json
# Moved: 001 (1165).json
# Moved: 001 (1187).json
# Moved: 001 (1168).json
# Moved: 001 (1118).json
# Moved: 001 (779).json
# Moved: 001 (781).json
# Moved: 001 (1183).json
# Moved: 001 (1191).json
# Moved: 001 (1189).json
# Moved: 001 (1190).json
# Moved: 001 (1188).json
# Moved: 001 (1258).json
# Moved: 001 (1193).json
# Moved: 001 (1226).json
# Moved: 001 (1202).json
# Moved: 001 (1207).json
# Moved: 001 (1194).json
# Moved: 001 (1233).json
# Moved: 001 (1232).json
# Moved: 001 (1234).json
# Moved: 001 (1195).json
# Moved: 001 (1268).json
# Moved: 001 (1229).json
# Moved: 001 (1278).json
# Moved: 001 (1276).json
# Moved: 001 (1265).json
# Moved: 001 (1199).json
# Moved: 001 (1272).json
# Moved: 001 (1267).json
# Moved: 001 (1282).json
# Moved: 001 (1274).json
# Moved: 001 (1334).json
# Moved: 001 (1273).json
# Moved: 001 (1338).json
# Moved: 001 (1306).json
# Moved: 001 (1350).json
# Moved: 001 (1284).json
# Moved: 001 (1288).json
# Moved: 001 (1312).json
# Moved: 001 (1275).json
# Moved: 001 (1336).json
# Moved: 001 (1352).json
# Moved: 001 (1307).json
# Moved: 001 (1370).json
# Moved: 001 (1357).json
# Moved: 001 (1341).json
# Moved: 001 (1349).json
# Moved: 001 (1323).json
# Moved: 001 (1320).json
# Moved: 001 (1371).json
# Moved: 001 (1339).json
# Moved: 001 (1380).json
# Moved: 001 (1356).json
# Moved: 001 (1354).json
# Moved: 001 (1353).json
# Moved: 001 (1377).json
# Moved: 001 (1468).json
# Moved: 001 (1379).json
# Moved: 001 (1423).json
# Moved: 001 (1394).json
# Moved: 001 (1419).json
# Moved: 001 (1487).json
# Moved: 001 (1395).json
# Moved: 001 (1431).json
# Moved: 001 (1399).json
# Moved: 001 (1397).json
# Moved: 001 (1412).json
# Moved: 001 (1437).json
# Moved: 001 (1448).json
# Moved: 001 (1461).json
# Moved: 001 (1501).json
# Moved: 001 (1511).json
# Moved: 001 (1512).json
# Moved: 001 (1482).json
# Moved: 001 (1553).json
# Moved: 001 (1552).json
# Moved: 001 (1541).json
# Moved: 001 (1530).json
# Moved: 001 (1595).json
# Moved: 001 (1540).json
# Moved: 001 (1612).json
# Moved: 001 (1624).json
# Moved: 001 (1625).json
# Moved: 001 (1632).json
# Moved: 001 (1574).json
# Moved: 001 (1633).json
# Moved: 001 (1596).json
# Moved: 001 (1636).json
# Moved: 001 (1629).json
# Moved: 001 (1628).json
# Moved: 001 (1638).json
# Moved: 001 (1631).json
# Moved: 001 (1634).json
# Moved: 001 (1641).json
# Moved: 001 (1655).json
# Moved: 001 (1646).json
# Moved: 001 (1660).json
# Moved: 001 (1665).json
# Moved: 001 (1643).json
# Moved: 001 (1668).json
# Moved: 001 (1670).json
# Moved: 001 (1673).json
# Moved: 001 (1697).json
# Moved: 001 (1693).json
# Moved: 001 (1688).json
# Moved: 001 (1671).json
# Moved: 001 (1698).json
# Moved: 001 (1725).json
# Moved: 001 (1733).json
# Moved: 001 (1715).json
# Moved: 001 (1734).json
# Moved: 001 (1726).json
# Moved: 001 (1719).json
# Moved: 001 (1736).json
# Moved: 001 (1743).json
# Moved: 001 (1757).json
# Moved: 001 (1744).json
# Moved: 001 (1783).json
# Moved: 001 (1758).json
# Moved: 001 (1809).json
# Moved: 001 (1787).json
# Moved: 001 (1771).json
# Moved: 001 (1825).json
# Moved: 001 (1859).json
# Moved: 001 (1828).json
# Moved: 001 (1852).json
# Moved: 001 (1879).json
# Moved: 001 (1880).json
# Moved: 001 (1881).json
# Moved: 001 (1882).json
# Moved: 001 (1894).json
# Moved: 001 (1895).json
# Moved: 001 (1897).json
# Moved: 001 (1900).json
# Moved: 001 (1901).json
# Moved: 001 (1903).json
# Moved: 001 (1921).json
# Moved: 001 (1922).json
# Moved: 001 (1923).json
# Moved: 001 (1935).json
# Moved: 001 (1937).json
# Moved: 001 (1941).json
# Moved: 001 (1942).json
# Moved: 001 (1943).json
# Moved: 001 (1950).json
# Moved: 001 (1954).json
# Moved: 001 (1965).json
# Moved: 001 (1966).json
# Moved: 001 (1967).json
# Moved: 001 (1982).json
# Moved: 001 (1978).json
# Moved: 001 (1989).json
# Moved: 001 (2007).json
# Moved: 001 (1991).json
# Moved: 001 (2009).json
# Moved: 001 (2010).json
# Moved: 001 (2022).json
# Moved: 001 (2024).json
# Moved: 001 (2025).json
# Moved: 001 (2032).json
# Moved: 001 (2030).json
# Moved: 001 (2048).json
# Moved: 001 (2042).json
# Moved: 001 (2049).json
# Moved: 001 (2047).json
# Moved: 001 (2051).json
# Moved: 001 (2057).json
# Moved: 001 (2054).json
# Moved: 001 (2052).json
# Moved: 001 (2053).json
# Moved: 001 (2138).json
# Moved: 001 (2071).json
# Moved: 001 (2100).json
# Moved: 001 (2076).json
# Moved: 001 (2139).json
# Moved: 001 (2193).json
# Moved: 001 (2074).json
# Moved: 001 (2064).json
# Moved: 001 (2212).json
# Moved: 001 (2176).json
# Moved: 001 (2194).json
# Moved: 001 (2213).json
# Moved: 001 (2201).json
# Moved: 001 (2349).json
# Moved: 001 (2374).json
# Moved: 001 (2375).json
# Moved: 001 (2350).json
# Moved: 001 (2365).json
# Moved: 001 (2391).json
# Moved: 001 (2439).json
# Moved: 001 (2459).json
# Moved: 001 (2495).json
# Moved: 001 (2513).json
# Moved: 001 (2511).json
# Moved: 001 (2516).json
# Moved: 001 (2512).json
# Moved: 001 (2600).json
# Moved: 001 (2544).json
# Moved: 001 (2527).json
# Moved: 001 (2597).json
# Moved: 001 (2549).json
# Moved: 001 (2615).json
# Moved: 001 (2859).json
# Moved: 001 (2595).json
# Moved: 001 (2599).json
# Moved: 001 (2623).json
# Moved: 001 (2637).json
# Moved: 001 (2818).json
# Moved: 001 (2668).json
# Moved: 001 (2667).json
# Moved: 001 (2862).json
# Moved: 001 (2700).json
# Moved: 001 (2991).json
# Moved: 001 (3030).json
# Moved: 001 (2913).json
# Moved: 001 (3157).json
# Moved: 001 (3019).json
# Moved: 001 (3018).json
# Moved: 001 (2996).json
# Moved: 001 (3115).json
# Moved: 001 (3175).json
# Moved: 001 (3050).json
# Moved: 001 (3243).json
# Moved: 001 (3204).json
# Moved: 001 (3255).json
# Moved: 001 (3315).json
# Moved: 001 (3306).json
# Moved: 001 (3307).json
# Moved: 001 (3388).json
# Moved: 001 (3447).json
# Moved: 001 (3343).json
# Moved: 001 (3364).json
# Moved: 001 (3330).json
# Moved: 001 (3461).json
# Moved: 001 (3446).json
# Moved: 001 (3640).json
# Moved: 001 (3482).json
# Moved: 001 (3889).json
# Moved: 001 (3615).json
# Moved: 001 (3708).json
# Moved: 001 (3686).json
# Moved: 001 (3652).json
# Moved: 001 (3838).json
# Moved: 001 (3687).json
# Moved: 001 (3883).json
# Moved: 001 (3785).json
# Moved: 001 (3784).json
# Moved: 001 (3863).json
# Moved: 001 (501).json
# Moved: 001 (827).json
# Moved: 001 (832).json
# Moved: 001 (867).json
# Moved: 001 (889).json
# Moved: 001 (934).json
# Moved: 001 (1023).json
# Moved: 001 (999).json
# Moved: 001 (1012).json
# Moved: 001 (1106).json
# Moved: 001 (1107).json
# Moved: 001 (1139).json
# Moved: 001 (1212).json
# Moved: 001 (1217).json
# Moved: 001 (1216).json
# Moved: 001 (1223).json
# Moved: 001 (1243).json
# Moved: 001 (1230).json
# Moved: 001 (1248).json
# Moved: 001 (1264).json
# Moved: 001 (1262).json
# Moved: 001 (1251).json
# Moved: 001 (1304).json
# Moved: 001 (1277).json
# Moved: 001 (1301).json
# Moved: 001 (1317).json
# Moved: 001 (1319).json
# Moved: 001 (1324).json
# Moved: 001 (1326).json
# Moved: 001 (1369).json
# Moved: 001 (1358).json
# Moved: 001 (1361).json
# Moved: 001 (1362).json
# Moved: 001 (1360).json
# Moved: 001 (1402).json
# Moved: 001 (1406).json
# Moved: 001 (1449).json
# Moved: 001 (1766).json
# Moved: 001 (2362).json
# Moved: 001 (2515).json
# Moved: 001 (3256).json
# Moved: 001 (1224).json
# Moved: 001 (1337).json
# Moved: 001 (1414).json

# %%
# !pip install seedir emoji
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: seedir in /environment/miniconda3/lib/python3.7/site-packages (0.4.2)
# Requirement already satisfied: emoji in /environment/miniconda3/lib/python3.7/site-packages (2.9.0)
# Requirement already satisfied: natsort in /environment/miniconda3/lib/python3.7/site-packages (from seedir) (8.4.0)

# %%
import seedir as sd
sd.seedir('mmsegmentation/LSR16F656', style='emoji', depthlimit=1)
# Out:
# 📁 LSR16F656/
# ├─📁 images/
# └─📁 labelme_jsons/

# %% [markdown]
# ## 删除系统自动生成的多余文件

# %% [markdown]
# ### 查看待删除的多余文件

# %%
# !find . -iname '__MACOSX'

# %%
# !find . -iname '.DS_Store'

# %%
# !find . -iname '.ipynb_checkpoints'
# Out:
# ./.ipynb_checkpoints
# ./mmsegmentation/LSR16F656/.ipynb_checkpoints
# ./mmsegmentation/.ipynb_checkpoints

# %% [markdown]
# ### 删除多余文件

# %%
# !for i in `find . -iname '__MACOSX'`; do rm -rf $i;done

# %%
# !for i in `find . -iname '.DS_Store'`; do rm -rf $i;done

# %%
# !for i in `find . -iname '.ipynb_checkpoints'`; do rm -rf $i;done

# %% [markdown]
# ### 验证多余文件已删除

# %%
# !find . -iname '__MACOSX'

# %%
# !find . -iname '.DS_Store'

# %%
# !find . -iname '.ipynb_checkpoints'
# Out:
# ./.ipynb_checkpoints

# %% [markdown]
# ## 进入数据集目录

# %%
import os
import json
import numpy as np
import cv2
import shutil

from tqdm import tqdm

# %% [markdown]
# ## 数据集及类别信息

# %%
Dataset_Path = 'mmsegmentation/LSR16F656'

# %% [markdown]
# ## 每个类别的信息及画mask的顺序（按照由大到小，由粗到精的顺序）

# %%
# 0-背景，从 1 开始
class_info = [
    {'label':'outer_ring', 'type':'polygon', 'color':1},                    # polygon 多段线
    {'label':'inner_ring', 'type':'polygon', 'color':2}
]

# %% [markdown]
# ## 单张图像labelme转mask函数

# %%
def labelme2mask_single_img(img_path, labelme_json_path):
    '''
    输入原始图像路径和labelme标注路径，输出 mask
    '''
    
    img_bgr = cv2.imread(img_path)
    img_mask = np.zeros(img_bgr.shape[:2]) # 创建空白图像 0-背景
    
    with open(labelme_json_path, 'r', encoding='utf-8') as f:
        labelme = json.load(f)
        
    for one_class in class_info: # 按顺序遍历每一个类别
        for each in labelme['shapes']: # 遍历所有标注，找到属于当前类别的标注
            if each['label'] == one_class['label']:
                if one_class['type'] == 'polygon': # polygon 多段线标注

                    # 获取点的坐标
                    points = [np.array(each['points'], dtype=np.int32).reshape((-1, 1, 2))]

                    # 在空白图上画 mask（闭合区域）
                    img_mask = cv2.fillPoly(img_mask, points, color=one_class['color'])

                elif one_class['type'] == 'line' or one_class['type'] == 'linestrip': # line 或者 linestrip 线段标注

                    # 获取点的坐标
                    points = [np.array(each['points'], dtype=np.int32).reshape((-1, 1, 2))]

                    # 在空白图上画 mask（非闭合区域）
                    img_mask = cv2.polylines(img_mask, points, isClosed=False, color=one_class['color'], thickness=one_class['thickness']) 

                elif one_class['type'] == 'circle': # circle 圆形标注

                    points = np.array(each['points'], dtype=np.int32)

                    center_x, center_y = points[0][0], points[0][1] # 圆心点坐标

                    edge_x, edge_y = points[1][0], points[1][1]     # 圆周点坐标

                    radius = np.linalg.norm(np.array([center_x, center_y] - np.array([edge_x, edge_y]))).astype('uint32') # 半径

                    img_mask = cv2.circle(img_mask, (center_x, center_y), radius, one_class['color'], one_class['thickness'])

                else:
                    print('未知标注类型', one_class['type'])
                    
    return img_mask

# %% [markdown]
# ## labelme转mask-批量

# %%
os.chdir(Dataset_Path)
os.mkdir('masks')
os.chdir('images')

# %%
for img_path in tqdm(os.listdir()):
    
    try:
    
        labelme_json_path = os.path.join('../', 'labelme_jsons', '.'.join(img_path.split('.')[:-1])+'.json')

        img_mask = labelme2mask_single_img(img_path, labelme_json_path)

        mask_path = img_path.split('.')[0] + '.png'

        cv2.imwrite(os.path.join('../','masks',mask_path), img_mask)
    
    except Exception as E:
        print(img_path, '转换失败', E)
# Out:
# 100%|██████████| 656/656 [00:42<00:00, 15.56it/s]

# %% [markdown]
# ## 转换之后的mask保存在`masks`文件夹中

# %% [markdown]
# ## 重命名和删除文件夹

# %%
os.chdir('mmsegmentation/LSR16F656')
os.getcwd()
# Out:
# '/home/featurize/work/MMSegmentation_Tutorials-20230816/mmsegmentation/LSR16F656'

# %%
# !rm -rf labelme_jsons

# %%
os.chdir('../')
shutil.move('images', 'img_dir')
shutil.move('masks', 'ann_dir')
# !rm -rf labelme_jsons
os.chdir('../')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /environment/miniconda3/lib/python3.7/shutil.py in move(src, dst, copy_function)
#     565     try:
# --> 566         os.rename(src, real_dst)
#     567     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images' -> 'img_dir'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_19167/3374332040.py in <module>
#       1 os.chdir('../')
# ----> 2 shutil.move('images', 'img_dir')
#       3 shutil.move('masks', 'ann_dir')
#       4 get_ipython().system('rm -rf labelme_jsons')
#       5 os.chdir('../')
#
# /environment/miniconda3/lib/python3.7/shutil.py in move(src, dst, copy_function)
#     578             rmtree(src)
#     579         else:
# --> 580             copy_function(src, real_dst)
#     581             os.unlink(src)
#     582     return real_dst
#
# /environment/miniconda3/lib/python3.7/shutil.py in copy2(src, dst, follow_symlinks)
#     264     if os.path.isdir(dst):
#     265         dst = os.path.join(dst, os.path.basename(src))
# --> 266     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     267     copystat(src, dst, follow_symlinks=follow_symlinks)
#     268     return dst
#
# /environment/miniconda3/lib/python3.7/shutil.py in copyfile(src, dst, follow_symlinks)
#     118         os.symlink(os.readlink(src), dst)
#     119     else:
# --> 120         with open(src, 'rb') as fsrc:
#     121             with open(dst, 'wb') as fdst:
#     122                 copyfileobj(fsrc, fdst)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images'

# %% [markdown]
# ## 得到最终的语义分割数据集

# %% [markdown]
# ## 查看数据集目录结构

# %%
import seedir as sd
sd.seedir('LSR16F656', style='emoji', depthlimit=1)
# Out:
# 📁 LSR16F656/
# ├─📁 img_dir/
# └─📁 ann_dir/
